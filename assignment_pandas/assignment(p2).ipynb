# %% [markdown]
# *ques 1*

# %% [markdown]
# five functions of pandas lirary:

# %%
# i). read_csv
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# ii). Series
l = ['a','c','d','e','f','g','h','i','j']
s = pd.Series(l)
s
# Out:
# 0    a
# 1    c
# 2    d
# 3    e
# 4    f
# 5    g
# 6    h
# 7    i
# 8    j
# dtype: object

# %%
# iii). dataframe
d = {'key1' :[1,4,5,6,7],
     'key2':[5,9,7,8,6],
     'key3':[4,5,6,7,8]
}
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5     4
# 1     4     9     5
# 2     5     7     6
# 3     6     8     7
# 4     7     6     8

# %%
# iv). set_index()
df.set_index("Name")
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
# v). dropna
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %% [markdown]
# *ques 2*

# %%
df1 = pd.DataFrame({
    'A':[1,2,4,5],
    'B':[3,4,5,6],
    'C':[5,6,7,8],
})
df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df1['new_index'] = df1.index

# %%
def incr(x):
    if x == 0:
        return 1
    return x + 2
df1['new_index'] = df1['new_index'].apply(incr)

# %%
df1
# df1.set_index("new_index",inplace=True)
# Out:
#    A  B  C  new_index
# 0  1  3  5          1
# 1  2  4  6          3
# 2  4  5  7          4
# 3  5  6  8          5

# %% [markdown]
# *ques 3*

# %%
df  = pd.DataFrame({"val":[1,24,40,5,5,6,7]})

# %%
def find_sum(df):
    sum = 0
    for i in range(3):
        sum+=df['val'][i]
    print(sum)

find_sum(df)
# Out:
# 65

# %% [markdown]
# *ques 4*

# %%
def cnt_word(x):
    return len(x.split())

df = pd.DataFrame({"Text":['Anshul is a good boy',"what are u doing","i am good","i am learning data science"]})
df['word_count'] = df['Text'].apply(cnt_word)
df
# Out:
#                          Text  word_count
# 0        Anshul is a good boy           5
# 1            what are u doing           4
# 2                   i am good           3
# 3  i am learning data science           5

# %% [markdown]
# *ques 5*

# %% [markdown]
# Dataframe.size is used to calculate overall size of the the dataframe whearas Dataframe.shape used to get the dimentions of the dataframe. for eg:

# %%
x = df.size
y = df.shape

# %%
x
# Out:
# 8

# %%
y
# Out:
# (4, 2)

# %% [markdown]
# *ques 6*

# %% [markdown]
# pd.read_excel() is used for reading excel file

# %% [markdown]
# *ques 7*

# %%
df = pd.DataFrame({"Email":["anshulrawat541@gmail.com","rohansingh@gmail.com","rahul@gmail.com","soniya@gmail.com","sonalisingh@gmail.com"]})
df

def Usrname(x):
     i = 0
     str = ''
     while x[i]!='@':
         str+=x[i]
         i = i+1
     return str 

df['username'] = df['Email'].apply(Usrname)

# %%
df['username']
# Out:
# 0    anshulrawat541
# 1        rohansingh
# 2             rahul
# 3            soniya
# 4       sonalisingh
# Name: username, dtype: object

# %% [markdown]
# *ques 8*

# %%
df = pd.DataFrame({"A":[3,8,6,2,9],"B":[5,2,9,3,1],"C":[1,7,4,5,2]})
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
def create(df):
    new_df = df[(df['A']>5) & (df['B']<10)]
    return new_df

new_df = create(df)
new_df
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# *ques 9*

# %%
df = pd.DataFrame({"Values":[3,4,5,6,8,9,10,11]})

# %%
df["Values"].mean()
# Out:
# 7.0

# %%
df["Values"].median()
# Out:
# 7.0

# %%
df["Values"].std()
# Out:
# 2.9277002188455996

# %% [markdown]
# *ques 10*

# %%
df = pd.DataFrame({"Sales":[100000,20000,30000,4000000,2000000,500000,4000000,7000000,800000,900000,100000,2500000],"Date":["2023-01-01","2023-02-01","2023-02-23",'2023-03-10','2023-04-01','2023-05-023','2023-06-01','2023-07-01','2023-08-01','2023-09-01','2023-10-01','2023-11-01']})

# %%
df
# Out:
#       Sales         Date
# 0    100000   2023-01-01
# 1     20000   2023-02-01
# 2     30000   2023-02-23
# 3   4000000   2023-03-10
# 4   2000000   2023-04-01
# 5    500000  2023-05-023
# 6   4000000   2023-06-01
# 7   7000000   2023-07-01
# 8    800000   2023-08-01
# 9    900000   2023-09-01
# 10   100000   2023-10-01
# 11  2500000   2023-11-01

# %%
df['Moving_Average'] = df['Sales'].rolling(window=7).mean()
df['Moving_Average'].fillna(0,inplace=True)
df
# Out:
#       Sales         Date  Moving_Average
# 0    100000   2023-01-01    0.000000e+00
# 1     20000   2023-02-01    0.000000e+00
# 2     30000   2023-02-23    0.000000e+00
# 3   4000000   2023-03-10    0.000000e+00
# 4   2000000   2023-04-01    0.000000e+00
# 5    500000  2023-05-023    0.000000e+00
# 6   4000000   2023-06-01    1.521429e+06
# 7   7000000   2023-07-01    2.507143e+06
# 8    800000   2023-08-01    2.618571e+06
# 9    900000   2023-09-01    2.742857e+06
# 10   100000   2023-10-01    2.185714e+06
# 11  2500000   2023-11-01    2.257143e+06

# %% [markdown]
# *ques 11*

# %%
def add_weekday(df):
    df['Date'] = pd.to_datetime(df["Date"])
    df['Weekday'] = df['Date'].dt.strftime('%A')

data = {"Date":['2023-07-20','2023-07-21','2023-07-22']}
df = pd.DataFrame(data)
add_weekday(df)
print(df)
# Out:
#         Date   Weekday
# 0 2023-07-20  Thursday
# 1 2023-07-21    Friday
# 2 2023-07-22  Saturday

# %% [markdown]
# *ques 12*

# %%
def select_dates(df):
    df['Date'] = pd.to_datetime(df['Date'])
    val = (df['Date']>='2023-01-01') & (df['Date'] <= '2023-01-31')
    selected_rows = df[val]
    return selected_rows

data = {'Date': ['2023-01-15', '2023-01-25', '2023-02-10', '2023-01-05','2023-01-30']}
df = pd.DataFrame(data)
selected_dates = select_dates(df)
print(selected_dates)
# Out:
#         Date
# 0 2023-01-15
# 1 2023-01-25
# 3 2023-01-05
# 4 2023-01-30

# %% [markdown]
# *ques 13*

# %% [markdown]
# **to import pandas first and foremost library needs to be imported is : pandas library**
